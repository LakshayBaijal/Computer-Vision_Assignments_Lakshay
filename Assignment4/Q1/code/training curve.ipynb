# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1/README.md
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1/requirements.txt
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1/code/train.py
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1/code/kaggle_q1_pipeline.ipynb
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1/code/visualize.py
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1/code/cvt.py
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1/code/vit.py

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/lakshaybaijal
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1
# /kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1/code

# %%
import shutil, os

src = '/kaggle/input/datasets/lakshaybaijal/assignment-4-q1-cv/Q1'
dst = '/kaggle/working/Q1'
if not os.path.exists(dst):
    shutil.copytree(src, dst)
os.chdir('/kaggle/working/Q1/code')
print("Now in:", os.getcwd())
print("Files:", os.listdir())
# Out:
# Now in: /kaggle/working/Q1/code
# Files: ['train.py', 'visualize.py', 'cvt.py', 'vit.py', 'kaggle_q1_pipeline.ipynb']

# %%
# !python train.py --mode vit_patch --epochs 50 --output_root ../training_curves
# !python train.py --mode vit_hparam --epochs 50 --output_root ../training_curves
# !python train.py --mode vit_aug --epochs 50 --output_root ../training_curves
# !python train.py --mode vit_pos --epochs 50 --output_root ../training_curves
# !python train.py --mode cvt --epochs 50 --output_root ../training_curves
# Out:
# 100%|████████████████████████████████████████| 170M/170M [00:02<00:00, 79.6MB/s]
# [vit_patch_2] Epoch 1/50 | train_loss=1.8638 val_loss=1.7005 val_acc=37.73%
# [vit_patch_2] Epoch 2/50 | train_loss=1.6309 val_loss=1.4782 val_acc=46.50%
# [vit_patch_2] Epoch 3/50 | train_loss=1.4430 val_loss=1.3535 val_acc=50.17%
# [vit_patch_2] Epoch 4/50 | train_loss=1.3484 val_loss=1.2801 val_acc=52.93%
# [vit_patch_2] Epoch 5/50 | train_loss=1.2737 val_loss=1.2334 val_acc=55.32%
# [vit_patch_2] Epoch 6/50 | train_loss=1.2311 val_loss=1.1654 val_acc=57.51%
# [vit_patch_2] Epoch 7/50 | train_loss=1.1943 val_loss=1.1125 val_acc=59.71%
# [vit_patch_2] Epoch 8/50 | train_loss=1.1526 val_loss=1.1219 val_acc=59.11%
# [vit_patch_2] Epoch 9/50 | train_loss=1.1242 val_loss=1.1272 val_acc=59.32%
# [vit_patch_2] Epoch 10/50 | train_loss=1.1044 val_loss=1.0681 val_acc=62.21%
# [vit_patch_2] Epoch 11/50 | train_loss=1.0828 val_loss=1.0053 val_acc=63.43%
# ...

# %%
import shutil

# Zip the entire Q1 folder (including training_curves, visualizations, etc.)
shutil.make_archive('/kaggle/working/Q1_results', 'zip', '/kaggle/working/Q1')

print("Your results are zipped as Q1_results.zip in the Output section.")
# Out:
# Your results are zipped as Q1_results.zip in the Output section.
